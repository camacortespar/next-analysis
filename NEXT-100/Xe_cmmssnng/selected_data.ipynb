# %% [markdown]
# # $^{222}\text{Rn}$-$\alpha$ in $\text{Xe}$
#
# Load the sophronia/dorothea processed data, apply the selecting criteria of your preference and store all the dataframes for future analysis.

# %%
import sys
sys.path.append('/data_extra2/ccortesp/NEXT-100/')

import crudo
import os
import pandas as pd
import pickle

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Runs Information

# %%
# Select the runs of interest
runs_info = [
                # Drift field scan: Oct 2024
                # {"run_number": 14440, "cath_HV": 18e3, "EL_HV": 6e3, "duration": 42952},
                # {"run_number": 14456, "cath_HV": 19e3, "EL_HV": 6e3, "duration": 56420},
                # {"run_number": 14468, "cath_HV": 20e3, "EL_HV": 6e3, "duration": 55696},
                # {"run_number": 14484, "cath_HV": 21e3, "EL_HV": 6e3, "duration": 48240},
                # {"run_number": 14489, "cath_HV": 22e3, "EL_HV": 6e3, "duration": 42314},
                # {"run_number": 14498, "cath_HV": 23e3, "EL_HV": 6e3, "duration": 43161},
                # {"run_number": 14519, "cath_HV": 23e3, "EL_HV": 6e3, "duration": 43274},
                # {"run_number": 14522, "cath_HV": 23e3, "EL_HV": 6e3, "duration": 42801},
                # --- Gas recirculation: Nov 29 --- #
                # {"run_number": 14581, "cath_HV": 23e3, "EL_HV": 6e3, "duration": 76086},
                # {"run_number": 14582, "cath_HV": 23e3, "EL_HV": 6e3, "duration": 79541},
                # {"run_number": 14588, "cath_HV": 23e3, "EL_HV": 6e3, "duration": 55856},
                # EL voltage scan: Dic 2024
                # {"run_number": 14601, "cath_HV": 23e3, "EL_HV": 7e3, "duration": 77537},
                # {"run_number": 14608, "cath_HV": 23e3, "EL_HV": 8e3, "duration": 86414},
                # {"run_number": 14704, "cath_HV": 23e3, "EL_HV": 9e3, "duration": 52765},
    
                # # # # #  A L P H A   R U N S # # # # #
    
                # # Jan 2025
                # {"run_number": 14714, "duration": 64527, "OK": -1     , "LOST": -1     , "real_rate": -1    },
                # {"run_number": 14715, "duration": 84365, "OK": 2469062, "LOST": 2239303, "real_rate": 55.809},  # NO processed 
                # {"run_number": 14716, "duration": 17036, "OK": 495769 , "LOST": 451306 , "real_rate": 55.592},
                # {"run_number": 14720, "duration": 48518, "OK": -1     , "LOST": -1     , "real_rate": -1    },
                # {"run_number": 14733, "duration": 53881, "OK": 1587637, "LOST": 1429629, "real_rate": 55.998},
                # {"run_number": 14735, "duration": 84987, "OK": 2508569, "LOST": 2267982, "real_rate": 56.203},
                # {"run_number": 14737, "duration": 72705, "OK": 2153786, "LOST": 1960347, "real_rate": 56.586},
                # {"run_number": 14739, "duration": 87138, "OK": 2576630, "LOST": 2334343, "real_rate": 56.358},
                # {"run_number": 14741, "duration": 87755, "OK": 2592615, "LOST": 2349583, "real_rate": 56.318},
                # {"run_number": 14743, "duration": 82332, "OK": 2437984, "LOST": 2220643, "real_rate": 56.583},
                # {"run_number": 14745, "duration": 60990, "OK": 1803415, "LOST": 1636317, "real_rate": 56.398},
                # # --- NO Cold Getter: Jan 27 --- #
                # {"run_number": 14753, "duration": 86308, "OK": 2188547, "LOST": 1532351, "real_rate": 43.111},
                # {"run_number": 14765, "duration": 55978, "OK": 1259832, "LOST": 735202 , "real_rate": 35.639},
                # {"run_number": 14776, "duration": 47397, "OK": 957081 , "LOST": 481810 , "real_rate": 30.358},  # Data removed
                # {"run_number": 14780, "duration": 88503, "OK": 1600797, "LOST": 682246 , "real_rate": 25.796},
                # # Feb 2025
                # {"run_number": 14782, "duration": 85654, "OK": 1382153, "LOST": 506234 , "real_rate": 22.046},
                # {"run_number": 14784, "duration": 57290, "OK": 842541 , "LOST": 273581 , "real_rate": 19.481},
                # {"run_number": 14789, "duration": 74148, "OK": 976360 , "LOST": 277504 , "real_rate": 16.910},
                # # --- Zero Suppression --- #
                # {"run_number": 14803, "duration": 71721, "OK": 933727 , "LOST": 104677 , "real_rate": 14.478},
                # {"run_number": 14804, "duration": 65116, "OK": 680552 , "LOST": 156995 , "real_rate": 12.862},
                # # --- NO Zero Suppression --- #
                # {"run_number": 14811, "duration": -1   , "OK": -1     , "LOST": -1     , "real_rate": -1    },
                # {"run_number": 14814, "duration": 6344 , "OK": 55679  , "LOST": 10155  , "real_rate": 10.377},
                # {"run_number": 14815, "duration": 86232, "OK": 717786 , "LOST": 121527 , "real_rate": 9.733 },
                # {"run_number": 14816, "duration": 86580, "OK": 659265 , "LOST": 101374 , "real_rate": 8.785 },
                # {"run_number": 14817, "duration": 49662, "OK": 352203 , "LOST": 50474  , "real_rate": 8.108 },
                # {"run_number": 14828, "duration": 53609, "OK": 300827 , "LOST": 100405 , "real_rate": 7.484 },
                # # --- Re-processed with IC v2.3.1 --- #
                # {"run_number": 14829, "duration": 73042, "OK": 387003 , "LOST": 121249 , "real_rate": 6.958 },
                # {"run_number": 14834, "duration": 5779 , "OK": 32864  , "LOST": 3887   , "real_rate": 6.359 }, # Not re-processed
                # {"run_number": 14835, "duration": 11713, "OK": 66515  , "LOST": 7358   , "real_rate": 6.306 }, # Not re-processed
                # {"run_number": 14837, "duration": 55751, "OK": 294175 , "LOST": 31034  , "real_rate": 5.833 },
                # {"run_number": 14838, "duration": 87854, "OK": 431766 , "LOST": 42219  , "real_rate": 5.395 },
                # {"run_number": 14839, "duration": 84881, "OK": 401004 , "LOST": 37747  , "real_rate": 5.169 },
                # {"run_number": 14840, "duration": 55363, "OK": 401004 , "LOST": 37747  , "real_rate": 5.169 },  # Elog malfunction
                # # --- Alphas background runs --- #
                # March 2025
                {"run_number": 15042, "duration": 74298, "OK": 60823, "LOST": 116292},
                {"run_number": 15061, "duration": 75693, "OK": 62081, "LOST": 118790},
                {"run_number": 15062, "duration": 84783, "OK": 69564, "LOST": 133911},
                {"run_number": 15063, "duration": 79120, "OK": 65052, "LOST": 124131},
                {"run_number": 15076, "duration": 69316, "OK": 56775, "LOST": 108095},
            ]

# %% [markdown]
# ### _Raw_ Data

# %%
raw_data = {run["run_number"]: crudo.load_run_data(run, output='RECO/Events')[run["run_number"]] for run in runs_info}
# Out:
# RECO/Events: Run 15042 successfully stored with data shape: (87382792, 17)
# RECO/Events: Run 15061 successfully stored with data shape: (87638092, 17)
# RECO/Events: Run 15062 successfully stored with data shape: (97750504, 17)
# RECO/Events: Run 15063 successfully stored with data shape: (91771360, 17)
# RECO/Events: Run 15076 successfully stored with data shape: (79392673, 17)

# %% [markdown]
# ### Selected Data

# %%
def selection_criteria(group):
        """
        Selection criteria applied to each group (event-level).
        
        Parameters:
            group (pd.DataFrame): Grouped data corresponding to an individual event.
        
        Returns:
            bool: True if the group meets the selection criteria, otherwise False.
        """
        return (
                    # Multiplicity
                      (group['nS1'].sum() == 1)
                    & (group['nS2'].sum() == 1)
            
                    # S1
                    & (group['S1w'].sum() < 1250)
                    & (600 < group['S1e'].sum() < 2250)
                    & (group['S1t'].sum() > 150e3)
            
                    # S2
                    & (50 < group['S2w'].sum() < 250)
                    & (group['S2t'].sum() < 1650e3)
            
                    # 214Po-like events
                    & (group['S1h'].sum() >= 0.17 * group['S1e'].sum() - 56)  # Reject (>=) or select (<)
        )

# %%
# %%time
sel_data = {run["run_number"]: crudo.filter_run_data(run, raw_data, selection_criteria)[run["run_number"]] for run in runs_info}
# Out:
# Run 14829 successfully stored with selected data shape: (946, 26)
# Run 14837 successfully stored with selected data shape: (6582, 26)
# Run 14838 successfully stored with selected data shape: (8955, 26)
# Run 14839 successfully stored with selected data shape: (7472, 26)
# Run 14840 successfully stored with selected data shape: (4406, 26)
# CPU times: user 1min 46s, sys: 2.82 s, total: 1min 49s
# Wall time: 1min 46s

# %% [markdown]
# ## Dataframes Storage

# %%
# Dataframe name
df_name = 'Rn_background'

# Choose which data to store: sel_data or raw_data
data = raw_data

# Store the selected data
with open(f"/data_extra2/ccortesp/NEXT-100/data/{df_name}.pkl", "wb") as file:
    pickle.dump(data, file)
    
print('Listo mi pana, péguese un análisis sabroso!')
# Out:
# Listo mi pana, péguese un análisis sabroso!

# %% [markdown]
# #### Or do you wanna merge two different dataframes into one?

# %%
merged_data = crudo.merge_dfs(file1="/data_extra2/ccortesp/NEXT-100/Xe_cmmssnng/data/temp_runs.pkl", 
                              file2="/data_extra2/ccortesp/NEXT-100/Xe_cmmssnng/data/extra_runs.pkl", 
                              output_file="/data_extra2/ccortesp/NEXT-100/Xe_cmmssnng/data/alpha_runs.pkl")
# Out:
# Stored merged data in: /data_extra2/ccortesp/NEXT-100/Xe_cmmssnng/data/alpha_runs.pkl
